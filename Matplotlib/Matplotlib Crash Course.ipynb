# %% [markdown]
# # Matplot

# %% [markdown]
# ## Load Necessary Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Basic Graph

# %%
plt.plot([1, 2, 4, 5], [4,5, 6, 8])

# %%
x = [1, 3, 4, 5, 8, 8, 9, 11]
y = [3, 7, 5, 6, 9, 7, 8, 9]
plt.plot(x, y)
# plt.plot(x, y, 'r+')
plt.show()

# %%
x = [1, 3, 4, 5, 8, 8, 9, 11]
y = [3, 7, 5, 6, 9, 7, 8, 9]
plt.plot(x, y)
plt.title("Basic plot using matplotlib")
plt.xlabel("X Value")
plt.ylabel("Y Value")
plt.show()
